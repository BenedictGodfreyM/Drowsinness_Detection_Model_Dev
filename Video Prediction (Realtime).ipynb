# %%
import cv2
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
img_height = 224
img_width = 224
class_names = ['Closed_Eyes','Open_Eyes']
model = tf.keras.models.load_model("Models/Image_Classification_Model_epochs-4_epochssteps-200_valsteps-20_dataset-84898.h5")

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open WebCam!!!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
while True:
    ret, frame = cap.read()
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
    gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    eyes = eye_cascade.detectMultiScale(gray_img,1.1,4)
    for(x, y, w, h) in eyes:
        roi_gray = gray_img[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        eyess = eye_cascade.detectMultiScale(roi_gray)
        if len(eyess) == 0:
            print("Eyes are not detected!")
        else:
            for (ex, ey, ew, eh) in eyess:
                eyes_roi = roi_color[ey:ey+eh, ex:ex+ew]
    final_img = cv2.resize(eyes_roi, (img_height, img_width))
    final_img = np.expand_dims(final_img, axis=0)

    predictions = model.predict(final_img)
    score = tf.nn.softmax(predictions[0])
    if (class_names[np.argmax(score)] == "Open_Eyes"):
        status = "Open Eyes"
    else:
        status = "Closed Eyes"
    
    gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    print(face_cascade.empty())
    faces = face_cascade.detectMultiScale(gray_img,1.1,4)
    for(x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
    cv2.putText(frame, status, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 0, 255), 2, cv2.LINE_4)
    cv2.imshow("Drowsiness Detection", frame)

    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# False
# Eyes are not detected!
# Eyes are not detected!
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# False
# Eyes are not detected!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# False
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 28
#      26 gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      27 print(face_cascade.empty())
# ---> 28 faces = face_cascade.detectMultiScale(gray_img,1.1,4)
#      29 for(x, y, w, h) in faces:
#      30     cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
#
# KeyboardInterrupt:
